# %% [markdown]
# <a href="https://colab.research.google.com/github/tekmologi8/CaseStudy2DDS/blob/main/Q3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-013df8ac-0dd8-4e9f-b57b-e7935303e147" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-013df8ac-0dd8-4e9f-b57b-e7935303e147">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train_revised.csv to train_revised (1).csv

# %%
df = pd.read_csv('train_revised.csv')
df
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO    17-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2         5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 3         5777         19A          Mpesa      SGP18CL0ME    27-11-17
# 4         5778         11A          Mpesa      BM97HFRGL9    27-11-17
# ...        ...         ...            ...             ...         ...
# 51640    13826          9B          Mpesa      8V2XDDZR6V    20-04-18
# 51641    13809         18A          Mpesa      4PEBSVJSNK    20-04-18
# 51642    13809         17A          Mpesa      LVN64LZDNN    20-04-18
# 51643    13796         16B          Mpesa      REYBSKTYWN    20-04-18
# 51644    14304           7          Mpesa      AQN7FBUSGP    14-11-17
#
#       travel_time travel_from travel_to car_type  max_capacity
# 0            7:15      Migori   Nairobi      Bus            49
# ...

# %%
#Using regex to filter out MK in payment_receipt
df = pd.DataFrame(['payment_recipt'])
r = re.compile(".*MK.*")
filtered_df = filter(r.match, df)
#newdf = df.filter(regex = ".*MK.*")
print(filtered_df)

# %%
#Example
#Consider the following DataFrame:

df = pd.DataFrame({"ABC":[1,2,3],"BCD":[4,5,6],"E":[7,8,9]}, index=["a","b","c"])
df
# Out:
#    ABC  BCD  E
# a    1    4  7
# b    2    5  8
# c    3    6  9

# %%
#To get columns where the label contains the character "C":

df.filter(regex=".*C.*")
# Out:
#    ABC  BCD
# a    1    4
# b    2    5
# c    3    6

# %%
#To get columns where the label contains the character "C":

newdf = df.filter(regex=".C.")

newdf

# %%
#Example
#Consider the following DataFrame:

df = pd.DataFrame({"MARTIN":[1,2,3],"MUGA":[4,5,6],"NYANZA":[7,8,9]}, index=["a","b","c"])
df
# Out:
#    MARTIN  MUGA  NYANZA
# a       1     4       7
# b       2     5       8
# c       3     6       9

# %%
newdf = df.filter(regex=".*M.*")
newdf
# Out:
#    MARTIN  MUGA
# a       1     4
# b       2     5
# c       3     6

# %%
import pandas as pd
sheet_id ="175xctDWxFrhDEbJ7s8pzdbRifpDqtk5gwIzaAYd2yPg"
sheet_name = "train_revised"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
from pandas.io.parsers.readers import read_csv
pd.read_csv(url)
# Out:
#        ride_id seat_number payment_method payment_receipt travel_date  \
# 0         1442         15A          Mpesa      UZUEHCBUSO    17-10-17
# 1         5437         14A          Mpesa      TIHLBUSGTE    19-11-17
# 2         5710          8B          Mpesa      EQX8Q5G19O    26-11-17
# 3         5777         19A          Mpesa      SGP18CL0ME    27-11-17
# 4         5778         11A          Mpesa      BM97HFRGL9    27-11-17
# ...        ...         ...            ...             ...         ...
# 51640    13826          9B          Mpesa      8V2XDDZR6V    20-04-18
# 51641    13809         18A          Mpesa      4PEBSVJSNK    20-04-18
# 51642    13809         17A          Mpesa      LVN64LZDNN    20-04-18
# 51643    13796         16B          Mpesa      REYBSKTYWN    20-04-18
# 51644    14304           7          Mpesa      AQN7FBUSGP    14-11-17
#
#       travel_time travel_from travel_to car_type  max_capacity
# 0           07:15      Migori   Nairobi      Bus            49
# ...

# %%
#Using regex to filter out MK in payment_receipt
df = pd.DataFrame([4])
newdf = df.filter(regex = "RE.*")  #.*MK.*
print(newdf)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0]

# %%
df = pd.DataFrame({'a': range(5),'b': ['cat', 'dog', 'mouse', 'house', 'tree']})

regex = "se$"

series = df["b"]

df1 = series.str.contains(regex)

print(df1)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# Name: b, dtype: bool
